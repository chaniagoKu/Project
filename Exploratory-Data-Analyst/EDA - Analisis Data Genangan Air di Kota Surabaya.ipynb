# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FILE_LATIHAN/data genangan air Surabaya2.csv')
df
# Out:
#      _id                               Lokasi      Kecamatan      Kelurahan  \
# 0      1           Jl. Pakis Agosari (Yamaha)    Dukuh Pakis    Dukuh Pakis
# 1      2  Jl. Mayjend Sungkono - Darmo Park I    Dukuh Pakis    Dukuh Pakis
# 2      3    Jl. Mayjend Sungkono (Pom Bensin)    Dukuh Pakis    Dukuh Pakis
# 3      4                          Kp. Kebraon   Karangpilang     Warugunung
# 4      5              Jl. Lakar Santri RW.001    Lakarsantri     Bangkingan
# ..   ...                                  ...            ...            ...
# 239  240                            Jl. Kanwa      WONOKROMO          DARMO
# 240  241                 Per. Rungkut Harapan        Rungkut  Rungkut Kidul
# 241  242                        TANJUNGSARI I  SUKOMANUNGGAL    TANJUNGSARI
# 242  243                       Jl. Karangrejo      Wonokromo      Wonokromo
# 243  244                       Kp. Tambakdono         Benowo     Tambakdono
#
# ...

# %%
# melihat info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              244 non-null    int64
#  1   Lokasi           244 non-null    object
#  2   Kecamatan        244 non-null    object
#  3   Kelurahan        244 non-null    object
#  4   Rayon            244 non-null    object
#  5   Luas genangan    244 non-null    float64
#  6   Tinggi genangan  244 non-null    int64
#  7   Lama genangan    244 non-null    int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 15.4+ KB

# %%
# cek missing value
df.isna().sum()
# Out:
# _id                0
# Lokasi             0
# Kecamatan          0
# Kelurahan          0
# Rayon              0
# Luas genangan      0
# Tinggi genangan    0
# Lama genangan      0
# dtype: int64

# %%
# melihat unique values dari kolom Lokasi
df['Lokasi'].unique()
# Out:
# array(['Jl. Pakis Agosari (Yamaha)',
#        'Jl. Mayjend Sungkono - Darmo Park I',
#        'Jl. Mayjend Sungkono (Pom Bensin)', 'Kp. Kebraon',
#        'Jl. Lakar Santri RW.001', 'Lontar Lidah Kulon',
#        'Jl. Babatan Indah', 'Perumahan Lembah Harapan', 'Jl. Simo Hilir',
#        'Jl. Kupang Baru', 'Kp. Babatan dan sekitarnya',
#        'Jl. Wiyung (Gg. DPR)', 'Jl. Hayam Wuruk', 'Jl. Adityawarman',
#        'Jl. Jajar Tunggal', 'Jl. H. Abdul Wahab Siamin', 'Jl. Gajah Mada',
#        'Jl. Simo Rejo', 'Jl. Simo Langit', 'Jl. Dukuh Menanggal',
#        'Jl. Bangkingan', 'Jl. Lakarsantri (Jembatan Perbatasan)',
#        'Jl. Dukuh Pakis', 'Jl. Waru Gunung (Kedawung)',
#        'Jl. Waru Gunung (Rusun)', 'Kp. Lidah Kulon RW.005',
#        'Jl. Raya Simo Jawar', 'Jl. Suko Manunggal s/d Simo Jawar',
#        'Jl. Pattimura', 'Jl. Satelit Selatan', 'Jl. Satelit Indah',
#        'Jl. Darmo Indah Timur (Darmo Harapan)', 'Kp. Kandangan',
# ...

# %%
# melihat unique values dari kolom Kecamatan
df['Kecamatan'].unique()
# Out:
# array(['Dukuh Pakis', 'Karangpilang', 'Lakarsantri', 'Wiyung',
#        'Sukomanunggal', 'Wonokromo', 'Gayungan', 'Benowo',
#        'Pabean Cantikan', 'Tandes', 'Asemrowo', 'Sambikerep', 'Sawahan',
#        'Jambangan', 'Rungkut', 'Pakal', 'Gubeng', 'Krembangan',
#        'Sukolilo', 'Tenggilis Mejoyo', 'Siwalan Kerto', 'Wonocolo',
#        'Ketintang', 'Bulak', 'Kenjeran', 'Mulyorejo', 'Semampir',
#        'Tambaksari', 'Wonokoromo', 'Simokerto', 'Genteng', 'Bubutan',
#        'Tegalsari', 'KREMBANGAN', 'SAWAHAN', 'WIYUNG', 'LAKARSANTRI',
#        'WONOKROMO', 'GENTENG', 'MULYOREJO', 'SUKOLILO', 'GUBENG',
#        'SUKOMANUNGGAL'], dtype=object)

# %%
# melihat unique values dari kolom Kelurahan
df['Kelurahan'].unique()
# Out:
# array(['Dukuh Pakis', 'Warugunung', 'Bangkingan', 'Lidah Kulon',
#        'Babatan', 'Lidah Wetan', 'Simomulyo', 'Dukuh Kupang', 'Wiyung',
#        'Sawunggaling', 'Wonokromo', 'Jajar Tunggal', 'Dukuh Menanggal',
#        'Sono Kwijenan', 'Tanjungsari', 'Kandangan', 'Bongkaran',
#        'Balongsari', 'Manukan Kulon', 'Tandes', 'Pradah Kali Kendal',
#        'Asemrowo', 'Babat Jerawat', 'Benowo', 'Bringin', 'Lontar',
#        'Banyuurip', 'Jambangan', 'Medokan Ayu', 'Pakis', 'Sawahan',
#        'Pucang Sewu', 'Karah', 'Romo Kalisari', 'Dupak', 'Sumber Rejo',
#        'Sememi', 'Romokalisari', 'Klampis Ngasem', 'Pakal', 'Made',
#        'Menur Pumougan', 'Kutisari', 'Kedung Baruk', 'Penjaringansari',
#        'Rungkut Kidul', 'Keputih', 'Siwalan Kerto', 'Bendul Merisi',
#        'Panjang Jiwo', 'Menur Pumpungan', 'Baratajaya', 'Ketintang',
#        'Nyamplungan', 'Kedung Cowek', 'Gubeng', 'Kertajaya', 'Mojo',
# ...

# %%
# melihat unique values dari kolom Rayon
df['Rayon'].unique()
# Out:
# array(['Rayon Wiyung', 'Rayon Tandes', 'Rayon Jambangan', 'Rayon Gubeng',
#        'Rayon Genteng'], dtype=object)

# %%
# merubah tipe data pada kolom Luas genangan agar dapat diurutkan
df['Luas genangan'] = df['Luas genangan'].astype('int').to_frame()
df
# Out:
#      _id                               Lokasi      Kecamatan      Kelurahan  \
# 0      1           Jl. Pakis Agosari (Yamaha)    Dukuh Pakis    Dukuh Pakis
# 1      2  Jl. Mayjend Sungkono - Darmo Park I    Dukuh Pakis    Dukuh Pakis
# 2      3    Jl. Mayjend Sungkono (Pom Bensin)    Dukuh Pakis    Dukuh Pakis
# 3      4                          Kp. Kebraon   Karangpilang     Warugunung
# 4      5              Jl. Lakar Santri RW.001    Lakarsantri     Bangkingan
# ..   ...                                  ...            ...            ...
# 239  240                            Jl. Kanwa      WONOKROMO          DARMO
# 240  241                 Per. Rungkut Harapan        Rungkut  Rungkut Kidul
# 241  242                        TANJUNGSARI I  SUKOMANUNGGAL    TANJUNGSARI
# 242  243                       Jl. Karangrejo      Wonokromo      Wonokromo
# 243  244                       Kp. Tambakdono         Benowo     Tambakdono
#
# ...

# %%
# cek tipe data lagi
df.dtypes
# Out:
# _id                 int64
# Lokasi             object
# Kecamatan          object
# Kelurahan          object
# Rayon              object
# Luas genangan       int32
# Tinggi genangan     int64
# Lama genangan       int64
# dtype: object

# %% [markdown]
# ## Daerah Rayon mana dengan rata-rata Luas genangan air tertinggi?

# %%
# mengurutkan data berdasarkan kolom Luas genangan
sort_luas = df.sort_values(by='Luas genangan', ascending=False)
sort_luas
# Out:
#      _id                              Lokasi        Kecamatan    Kelurahan  \
# 241  242                       TANJUNGSARI I    SUKOMANUNGGAL  TANJUNGSARI
# 78    79      Kp. Simo Mulyo, Jl. Gumuk Bogo    Sukomanunggal    Simomulyo
# 79    80    Kp. Simo Mulyo, Jl. Kali Kundang    Sukomanunggal    Simomulyo
# 243  244                      Kp. Tambakdono           Benowo   Tambakdono
# 69    70                     Kp. Sumber Rejo            Pakal  Sumber Rejo
# ..   ...                                 ...              ...          ...
# 109  110                       Jl. Ketintang         Gayungan    Ketintang
# 110  111  Jl. Ketintang Madya dan sekitarnya        Ketintang    Ketintang
# 111  112                       Jl. Bongkaran  Pabean Cantikan    Bongkaran
# 112  113                      Jl. Songoyudan  Pabean Cantikan  Nyamplungan
# 122  123                           Jl. Kanwa        Wonokromo        Darmo
#
#                Rayon  Luas genangan  Tinggi genangan  Lama genangan
# ...

# %%
# cek 10 data teratas dari data yang diurutkan berdasarkan kolom Luas genangan
sort_luas.head(10)
# Out:
#      _id                            Lokasi         Kecamatan      Kelurahan  \
# 241  242                     TANJUNGSARI I     SUKOMANUNGGAL    TANJUNGSARI
# 78    79    Kp. Simo Mulyo, Jl. Gumuk Bogo     Sukomanunggal      Simomulyo
# 79    80  Kp. Simo Mulyo, Jl. Kali Kundang     Sukomanunggal      Simomulyo
# 243  244                    Kp. Tambakdono            Benowo     Tambakdono
# 69    70                   Kp. Sumber Rejo             Pakal    Sumber Rejo
# 118  119                  Jl. Pucang Jajar            Gubeng      Kertajaya
# 242  243                    Jl. Karangrejo         Wonokromo      Wonokromo
# 68    69                       Dupak Rukun        Krembangan          Dupak
# 105  106         Perumahan Rungkut Harapan           Rungkut  Rungkut Kidul
# 100  101               Jl. Panjang Jiwo IX  Tenggilis Mejoyo   Panjang Jiwo
#
#                Rayon  Luas genangan  Tinggi genangan  Lama genangan
# ...

# %% [markdown]
# Jika dilihat dari tabel diatas bahwa Rayon Tandes memiliki rata-rata Luas genangan air tertinggi.

# %%
# menampilkan data berdasarkan kolom Rayon dari Rayon Tandes
rayon_tandes = df[df['Rayon']=='Rayon Tandes']
rayon_tandes
# Out:
#      _id                                 Lokasi      Kecamatan  \
# 8      9                         Jl. Simo Hilir  Sukomanunggal
# 9     10                        Jl. Kupang Baru    Dukuh Pakis
# 17    18                          Jl. Simo Rejo  Sukomanunggal
# 18    19                        Jl. Simo Langit  Sukomanunggal
# 26    27                    Jl. Raya Simo Jawar  Sukomanunggal
# 27    28      Jl. Suko Manunggal s/d Simo Jawar  Sukomanunggal
# 28    29                          Jl. Pattimura  Sukomanunggal
# 29    30                    Jl. Satelit Selatan  Sukomanunggal
# 30    31                      Jl. Satelit Indah  Sukomanunggal
# 31    32  Jl. Darmo Indah Timur (Darmo Harapan)  Sukomanunggal
# 32    33                          Kp. Kandangan         Benowo
# 34    35                         Kp. Balongsari         Tandes
# 35    36                      Kp. Manukan Kulon         Tandes
# 36    37      Jl. Margomulyo (Bawah Jalan Tol))         Tandes
# ...

# %%
# melihat total dari seluruh baris Rayon Tandes
rayon_tandes.count()
# Out:
# _id                56
# Lokasi             56
# Kecamatan          56
# Kelurahan          56
# Rayon              56
# Luas genangan      56
# Tinggi genangan    56
# Lama genangan      56
# dtype: int64

# %%
# melihat jumlah nilai setiap kolom dari tabel berdasarkan Rayon Tandes
rayon_tandes.sum()
# Out:
# _id                                                             3439
# Lokasi             Jl. Simo HilirJl. Kupang BaruJl. Simo RejoJl. ...
# Kecamatan          SukomanunggalDukuh PakisSukomanunggalSukomanun...
# Kelurahan          SimomulyoDukuh KupangSimomulyoSimomulyoSimomul...
# Rayon              Rayon TandesRayon TandesRayon TandesRayon Tand...
# Luas genangan                                                    132
# Tinggi genangan                                                  685
# Lama genangan                                                   1081
# dtype: object

# %%
# melakukan pengecekan kembali dengan pivot table
pivot = df.pivot_table(df, index = 'Rayon', aggfunc='sum')
pivot
# Out:
#                  Lama genangan  Luas genangan  Tinggi genangan    _id
# Rayon
# Rayon Genteng             1172             20              570   8924
# Rayon Gubeng              1409             61              601  11638
# Rayon Jambangan           1090             87              325   4472
# Rayon Tandes              1081            132              685   3439
# Rayon Wiyung               626             45              484   1417

# %% [markdown]
# ## Daerah Rayon mana dengan rata-rata Tinggi genangan air tertinggi?

# %%
# mengurutkan data berdasarkan kolom Luas genangan
sort_tinggi = df.sort_values(by='Tinggi genangan', ascending=False)
sort_tinggi.head(10)
# Out:
#      _id                          Lokasi    Kecamatan           Kelurahan  \
# 14    15               Jl. Jajar Tunggal       Wiyung       Jajar Tunggal
# 25    26          Kp. Lidah Kulon RW.005  Lakarsantri         Lidah Kulon
# 4      5         Jl. Lakar Santri RW.001  Lakarsantri          Bangkingan
# 124  125                       Jl. Randu     Kenjeran      Sidotopo Wetan
# 15    16       Jl. H. Abdul Wahab Siamin  Dukuh Pakis         Dukuh Pakis
# 47    48                Kp.Candi Lempung   Sambikerep              Lontar
# 184  185  Jl. Raden Saleh dan sekitarnya      Bubutan             Bubutan
# 198  199                       Jl. Demak      Bubutan              Gundih
# 210  211                   Jl. Pawiyatan      Bubutan             Bubutan
# 215  216              Jl. Kemayoran Baru   Krembangan  Krembangan Selatan
#
#              Rayon  Luas genangan  Tinggi genangan  Lama genangan
# 14    Rayon Wiyung              0               50             80
# ...

# %% [markdown]
# Jika dilihat dari tabel diatas bahwa Rayon Wiyung memiliki rata-rata Tinggi genangan air tertinggi.

# %%
# melakukan pengecekan kembali dengan menggunakan visualisasi 
data = df.groupby('Rayon')['Tinggi genangan'].sum().plot(kind='bar')

# %%
# cek Rayon Tandes mengapa bisa tertinggi pada grafik?
h = df[df['Rayon']=='Rayon Tandes']
h.sort_values(by='Tinggi genangan', ascending=False)
# Out:
#      _id                                 Lokasi      Kecamatan  \
# 48    49                        Kp. Simo Gunung        Sawahan
# 31    32  Jl. Darmo Indah Timur (Darmo Harapan)  Sukomanunggal
# 9     10                        Jl. Kupang Baru    Dukuh Pakis
# 47    48                       Kp.Candi Lempung     Sambikerep
# 46    47                 Jl. Raya Bringin Indah     Sambikerep
# 40    41        Kp. Dukuh Langkir Babat Jerawat         Benowo
# 81    82                        Jl. Raya Lontar     Sambikerep
# 77    78                              Jl. Jawar  Sukomanunggal
# 32    33                          Kp. Kandangan         Benowo
# 76    77               Jl. Darmo Indah Barat II  Sukomanunggal
# 75    76              Jl. Ngemplak (Made Utara)     Sambikerep
# 73    74                              Jl. Pakal         Benowo
# 37    38                 Jl. Darmo Permai Timur    Dukuh Pakis
# 56    57     Jl. Jurang Kuping s/d Jl. Rejosari          Pakal
# ...

# %%
# cek rata-rata untuk mendapatkan hasil yang pasti antara Rayon Tandes dan Rayon Wiyung berdasarkan tinggi genangan air tertinggi
tandes = df[df['Rayon']=='Rayon Tandes']
wiyung = df[df['Rayon']=='Rayon Wiyung']

mean_tandes = tandes['Tinggi genangan'].mean()
print('Rata-rata tinggi genangan air Rayon Tandes :',mean_tandes)

mean_wiyung = wiyung['Tinggi genangan'].mean()
print('Rata-rata tinggi genangan air Rayon Wiyung :',mean_wiyung)
# Out:
# Rata-rata tinggi genangan air Rayon Tandes : 12.232142857142858
# Rata-rata tinggi genangan air Rayon Wiyung : 18.615384615384617

# %% [markdown]
# Berdasarkan hasil visualisasi dan tabel diatas, terlihat bahwa Rayon Tandes memiliki peringkat tertinggi karena memiliki jumlah yang lebih banyak dibandingkan dengan Rayon Wiyung. Akan tetapi, berdasarkan rata-rata tinggi genangan air tertinggi yaitu tetap dimiliki oleh Rayon Wiyung.

# %% [markdown]
# ## Daerah Rayon mana dengan rata-rata Lama genangan air paling lama?

# %%
# mengurutkan data berdasarkan kolom Lama genangan
sort_lama = df.sort_values(by='Lama genangan', ascending=False)
sort_lama.head(10)
# Out:
#      _id                               Lokasi    Kecamatan       Kelurahan  \
# 124  125                            Jl. Randu     Kenjeran  Sidotopo Wetan
# 69    70                      Kp. Sumber Rejo        Pakal     Sumber Rejo
# 138  139                        Jl. Hang Tuah     Semampir           Ujung
# 14    15                    Jl. Jajar Tunggal       Wiyung   Jajar Tunggal
# 147  148                       Kp. Ploso Baru   Tambaksari    Pacar Keling
# 150  151                     Kp. Karang Empat   Tambaksari           Ploso
# 98    99                   Kp. Merisi Selatan     Wonocolo   Bendul Merisi
# 129  130                  Perumahan Mulyosari    Mulyorejo        Kalisari
# 128  129     Jl. Kalijudan (Perbatasan Ploso)    Mulyorejo       Kalijudan
# 1      2  Jl. Mayjend Sungkono - Darmo Park I  Dukuh Pakis     Dukuh Pakis
#
#                Rayon  Luas genangan  Tinggi genangan  Lama genangan
# 124     Rayon Gubeng              0               30             90
# ...

# %%
# melakukan pengecekan dengan pivot table berdasarkan jumlah data
pivot = df.pivot_table(df, index = 'Rayon', aggfunc='count')
pivot
# Out:
#                  Kecamatan  Kelurahan  Lama genangan  Lokasi  Luas genangan  \
# Rayon
# Rayon Genteng           44         44             44      44             44
# Rayon Gubeng            76         76             76      76             76
# Rayon Jambangan         42         42             42      42             42
# Rayon Tandes            56         56             56      56             56
# Rayon Wiyung            26         26             26      26             26
#
#                  Tinggi genangan  _id
# Rayon
# Rayon Genteng                 44   44
# Rayon Gubeng                  76   76
# Rayon Jambangan               42   42
# Rayon Tandes                  56   56
# Rayon Wiyung                  26   26

# %%
# melakukan pengecekan kembali dengan menggunakan visualisasi 
data = df.groupby('Rayon')['Lama genangan'].sum().plot(kind='bar')

# %%
# melakukan pengecekan kembali dengan menggunakan rata-rata setiap atribut
tandes = df[df['Rayon']=='Rayon Tandes']
wiyung = df[df['Rayon']=='Rayon Wiyung']
jambangan = df[df['Rayon']=='Rayon Jambangan']
gubeng = df[df['Rayon']=='Rayon Gubeng']
genteng = df[df['Rayon']=='Rayon Genteng']

mean_tandes = tandes['Lama genangan'].mean()
print('Rata-rata Lama genangan air Rayon Tandes :',mean_tandes)

mean_wiyung = wiyung['Lama genangan'].mean()
print('Rata-rata Lama genangan air Rayon Wiyung :',mean_wiyung)

mean_jambangan = jambangan['Lama genangan'].mean()
print('Rata-rata Lama genangan air Rayon Jambangan :',mean_jambangan)

mean_gubeng = gubeng['Lama genangan'].mean()
print('Rata-rata Lama genangan air Rayon Gubeng :',mean_gubeng)

mean_genteng = genteng['Lama genangan'].mean()
print('Rata-rata Lama genangan air Rayon Genteng :',mean_genteng)
# Out:
# Rata-rata Lama genangan air Rayon Tandes : 19.303571428571427
# Rata-rata Lama genangan air Rayon Wiyung : 24.076923076923077
# Rata-rata Lama genangan air Rayon Jambangan : 25.952380952380953
# Rata-rata Lama genangan air Rayon Gubeng : 18.539473684210527
# Rata-rata Lama genangan air Rayon Genteng : 26.636363636363637

# %% [markdown]
# Berdasarkan hasil visualisasi dan tabel diatas, terlihat bahwa Rayon Gubeng memiliki peringkat tertinggi karena memiliki jumlah yang lebih banyak dibandingkan dengan Rayon Genteng. Akan tetapi, berdasarkan rata-rata lama genangan air paling lama yaitu Rayon Genteng.

# %% [markdown]
# ## Bagaimana distribusi penyebaran dari luas genangan air?

# %%
plt.figure(figsize=(15,10))
sns.distplot(df['Luas genangan'], color='red')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Apakah ada hubungan antara luas dan tinggi genangan air?

# %%
# korelasi hubungan
df_kor = df.corr()
df_kor
# Out:
#                       _id  Luas genangan  Tinggi genangan  Lama genangan
# _id              1.000000       0.002509        -0.228225      -0.163956
# Luas genangan    0.002509       1.000000        -0.077056       0.056113
# Tinggi genangan -0.228225      -0.077056         1.000000       0.338228
# Lama genangan   -0.163956       0.056113         0.338228       1.000000

# %%
# menggunakan heatmap
sns.heatmap(df_kor, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(data=df, y='Tinggi genangan', x='Luas genangan')
# Out:
# <AxesSubplot:xlabel='Luas genangan', ylabel='Tinggi genangan'>

# %% [markdown]
# Hubungan antara Luas dan Tinggi genangan air yaitu -0,77 (Negatif Kuat). Berdasarkan penelitian dan hubungan yang didapatkan yaitu jika luas genangan air semakin meningkat maka tinggi genangan air akan semakin rendah.

# %% [markdown]
# # Kesimpulan dan Rekomendasi kepada Pemerintah Surabaya

# %% [markdown]
# Menurut pendapat saya, seharusnya pemerintah Kota Surabaya lebih menaikkan kebijakan dan arahan strategis penanganan permasalahan menyeluruh yang berkaitan dengan banjir dan kelangkaan air.
